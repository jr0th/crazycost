# %%
# %matplotlib inline

import numpy as np
import skimage.io
import matplotlib.pyplot as plt

import warnings

# %%
debug = True

# %%
dim1 = 64
dim2 = 64

# %%
N = 100

# %%
# numpy array
X = np.empty((N, dim1, dim2, 1), dtype=np.float)
# Y can be either 0, -1 or 1 extra dimension for seeds added
Y = np.empty((N, dim1, dim2, 4), dtype=np.ubyte)

for i in range(N):
    
    random_x = np.random.rand(dim1, dim2)
    random_y_image = np.random.randint(low=-1, high=2, size=(dim1,dim2))
    random_y_seed = np.random.randint(low=0, high=2, size=(dim1,dim2))
    
    X[i,:,:,:] = random_x.reshape((dim1, dim2, 1))
    Y[i,:,:,0] = random_y[:,:,0] == -1
    Y[i,:,:,1] = random_y[:,:,0] == 0
    Y[i,:,:,2] = random_y[:,:,0] == 1
    Y[i,:,:,3] = random_y_seed
    
    if(debug):
        plt.imshow(random_x)
        plt.show()
        plt.imshow(random_y_image)
        plt.show()

        plt.hist(random_x.flatten())
        plt.show()
        plt.hist(random_y_image.flatten())
        plt.show()
        
    warnings.simplefilter('ignore')
    skimage.io.imsave('../data/dummy_y3D/x/' + str(i) + '.png', random_x)
    skimage.io.imsave('../data/dummy_y3D/y/' + str(i) + '.png', random_y)
    
np.save('../data/dummy_y3D/x.npy', X)
np.save('../data/dummy_y3D/y.npy', Y)
