# %%
import numpy as np
import skimage.io
import matplotlib.pyplot as plt

# %%
N = 3

X = np.empty(shape=(N))

images = skimage.io.imread_collection('../images/images_sample/')

for i in range(N):
    
    # process image i
    image_i = skimage.io.imread('../images/images_sample/sample_{0:0>3}.png'.format(i))
    image_i = image_i / np.amax(image_i)
    
    X[i,:,:] = image_i
    
    if(debug):
        print(image_i.shape)
        
        plt.imshow(image_i)
        plt.show()

        plt.hist(image_i.flatten())
        plt.show()
        
    # process labels
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
